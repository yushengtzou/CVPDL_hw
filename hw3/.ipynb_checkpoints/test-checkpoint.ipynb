# %% [markdown]
# # Use BLIP-2 with no sample for "Image2Text"

# %% [markdown]
# Source: https://github.com/huggingface/blog/blob/main/zh/blip-2.md

# %%
import requests
from PIL import Image

# %%
import os
os.environ['HF_HOME'] = '/mnt/lab/2.course/112-1/cvpdl/hw3/cache'  # replace with the desired path on /mnt/lab

# %%
url = 'https://media.newyorker.com/cartoons/63dc6847be24a6a76d90eb99/master/w_1160,c_limit/230213_a26611_838.jpg'
image = Image.open(requests.get(url, stream=True).raw).convert('RGB')  
display(image.resize((596, 437)))
# Out:
# <PIL.Image.Image image mode=RGB size=596x437>

# %%
from transformers import AutoProcessor, Blip2ForConditionalGeneration
import torch

# %%
processor = AutoProcessor.from_pretrained("Salesforce/blip2-opt-2.7b")

# %%
model = Blip2ForConditionalGeneration.from_pretrained("Salesforce/blip2-opt-2.7b", torch_dtype=torch.float16)
# Out:
# ...
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/10.0G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/5.50G [00:00<?, ?B/s]

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)
